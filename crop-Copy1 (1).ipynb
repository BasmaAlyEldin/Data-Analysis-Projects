# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
file_path=("C:/Users/SOURCE/Downloads/crop_yield.xlsx")
df=pd.DataFrame()
df=pd.read_excel(file_path)

# %%
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df['Crop'].unique()
# Out:
# array(['Arecanut', 'Arhar/Tur', 'Castor seed', 'Coconut ', 'Cotton(lint)',
#        'Dry chillies', 'Gram', 'Jute', 'Linseed', 'Maize', 'Mesta',
#        'Niger seed', 'Onion', 'Other  Rabi pulses', 'Potato',
#        'Rapeseed &Mustard', 'Rice', 'Sesamum', 'Small millets',
#        'Sugarcane', 'Sweet potato', 'Tapioca', 'Tobacco', 'Turmeric',
#        'Wheat', 'Bajra', 'Black pepper', 'Cardamom', 'Coriander',
#        'Garlic', 'Ginger', 'Groundnut', 'Horse-gram', 'Jowar', 'Ragi',
#        'Cashewnut', 'Banana', 'Soyabean', 'Barley', 'Khesari', 'Masoor',
#        'Moong(Green Gram)', 'Other Kharif pulses', 'Safflower',
#        'Sannhamp', 'Sunflower', 'Urad', 'Peas & beans (Pulses)',
#        'other oilseeds', 'Other Cereals', 'Cowpea(Lobia)',
#        'Oilseeds total', 'Guar seed', 'Other Summer Pulses', 'Moth'],
#       dtype=object)

# %%
df['Crop'].nunique()
# Out:
# 55

# %%
df['Crop'].value_counts().sort_values()
# Out:
# Other Summer Pulses        10
# Oilseeds total             29
# Guar seed                  63
# Cardamom                   74
# Khesari                    75
# Moth                      110
# other oilseeds            126
# Black pepper              126
# Cashewnut                 134
# Cowpea(Lobia)             134
# Other Cereals             146
# Sannhamp                  160
# Arecanut                  162
# Safflower                 169
# Coconut                   172
# Jute                      181
# Niger seed                192
# Coriander                 199
# Tapioca                   201
# Mesta                     210
# Banana                    245
# Garlic                    250
# Sweet potato              273
# Barley                    297
# Castor seed               300
# Linseed                   308
# Ginger                    323
# Masoor                    324
# Turmeric                  337
# Soyabean                  349
# Other  Rabi pulses        355
# ...

# %%
df[df['Crop']=='Rice'].plot(x='State', y='Production').bar
# Out:
# <bound method Axes.bar of <Axes: xlabel='State'>>

# %%
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df[['Production', 'Fertilizer','Pesticide','Yield']].describe().round()
# Out:
#          Production    Fertilizer   Pesticide    Yield
# count  1.968900e+04  1.968900e+04     19689.0  19689.0
# mean   1.643594e+07  2.410331e+07     48848.0     80.0
# std    2.630568e+08  9.494600e+07    213287.0    878.0
# min    0.000000e+00  5.400000e+01         0.0      0.0
# 25%    1.393000e+03  1.880150e+05       357.0      1.0
# 50%    1.380400e+04  1.234957e+06      2422.0      1.0
# 75%    1.227180e+05  1.000385e+07     20042.0      2.0
# max    6.326000e+09  4.835407e+09  15750511.0  21105.0

# %%
df.astype('object').describe()
# Out:
#          Crop  Crop_Year       Season      State     Area  Production  \
# count   19689      19689        19689      19689  19689.0       19689
# unique     55         24            6         30  13644.0       14016
# top      Rice       2019  Kharif       Karnataka      1.0           0
# freq     1197       1079         8232       1432    113.0         112
#
#         Annual_Rainfall  Fertilizer  Pesticide    Yield
# count        19689.0000     19689.0   19689.00  19689.0
# unique         634.0000     18598.0   17405.00  13551.0
# top           1434.5875       150.8       0.99      1.0
# freq           360.0000        11.0      19.00    167.0

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Karnataka', 'Kerala', 'Meghalaya', 'West Bengal',
#        'Puducherry', 'Goa', 'Andhra Pradesh', 'Tamil Nadu', 'Odisha',
#        'Bihar', 'Gujarat', 'Madhya Pradesh', 'Maharashtra', 'Mizoram',
#        'Punjab', 'Uttar Pradesh', 'Haryana', 'Himachal Pradesh',
#        'Tripura', 'Nagaland', 'Chhattisgarh', 'Uttarakhand', 'Jharkhand',
#        'Delhi', 'Manipur', 'Jammu and Kashmir', 'Telangana',
#        'Arunachal Pradesh', 'Sikkim'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 30

# %%
df['Crop'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df['Season'].unique()
# Out:
# array(['Whole Year ', 'Kharif     ', 'Rabi       ', 'Autumn     ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
df['State'].value_counts()
# Out:
# Karnataka            1432
# Andhra Pradesh       1266
# West Bengal          1094
# Chhattisgarh          915
# Bihar                 896
# Madhya Pradesh        845
# Uttar Pradesh         825
# Tamil Nadu            822
# Gujarat               817
# Maharashtra           770
# Uttarakhand           764
# Odisha                760
# Assam                 731
# Nagaland              689
# Puducherry            670
# Meghalaya             649
# Haryana               631
# Jammu and Kashmir     631
# Himachal Pradesh      616
# Kerala                534
# Manipur               444
# Tripura               441
# Mizoram               416
# Telangana             397
# Punjab                397
# Arunachal Pradesh     292
# Jharkhand             270
# Goa                   246
# Sikkim                226
# Delhi                 203
# Name: State, dtype: int64

# %%
df[df['Crop']=='Rice'].plot(x='State', y='Production')
# Out:
# <Axes: xlabel='State'>

# %%
gp=df.groupby('Crop')['Production'].sum().sort_values()
gp
#Coconut is the most production
# Out:
# Crop
# Other Summer Pulses              8394
# Cardamom                       255497
# Sannhamp                       419887
# Cowpea(Lobia)                  732573
# Moth                           913750
# Other Cereals                 1661859
# Black pepper                  2095650
# Linseed                       3187572
# Safflower                     3241790
# Coriander                     3242496
# Cashewnut                     3737207
# Other Kharif pulses           5246413
# Horse-gram                    5276782
# Other  Rabi pulses            6437766
# Khesari                       7115452
# Guar seed                     7227527
# Turmeric                      9688934
# other oilseeds               10033173
# Sweet potato                 10409540
# Small millets                13429255
# Sesamum                      13542969
# Mesta                        14052802
# Peas & beans (Pulses)        14310509
# Sunflower                    14644638
# ...

# %%
sn.histplot(gp)
#فيها حاجه غلط
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sn.histplot(gp)
#
# NameError: name 'sn' is not defined

# %%
gp2=df.groupby(['State'])['Crop'].value_counts()
gp2
# Out:
# State           Crop
# Andhra Pradesh  Groundnut             46
#                 Horse-gram            46
#                 Jowar                 46
#                 Maize                 46
#                 Moong(Green Gram)     46
#                                       ..
# West Bengal     Ginger                11
#                 Other  Rabi pulses    11
#                 Cardamom              10
#                 Moth                   4
#                 Garlic                 1
# Name: Crop, Length: 995, dtype: int64

# %%
sn.boxplot(gp2)
# Out:
# <Axes: >

# %%
gp_season=df.groupby(['Season'])['Production'].sum().sort_values()
gp_season
# Out:
# Season
# Autumn             84406651
# Summer            243731156
# Winter            586507936
# Rabi             2837368229
# Kharif           5402484780
# Whole Year     314452748974
# Name: Production, dtype: int64

# %%
df.groupby('Season')['Crop_Year'].value_counts().unstack().plot.bar()
# Out:
# <Axes: xlabel='Season'>

# %%
df['Fertilizer'].plot(x='Fertilizer', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sn.distplot(df['Fertilizer'])
# Out:
# C:\Users\التوحيد\AppData\Local\Temp\ipykernel_9972\2365776669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['Fertilizer'])
# <Axes: xlabel='Fertilizer', ylabel='Density'>

# %%
gp2=df.groupby(['State'])['Crop'].value_counts().plot(kind='hist')

# %%
numdf = df.select_dtypes(include=[np.number])
numdf
# Out:
#        Crop_Year      Area  Production  Annual_Rainfall   Fertilizer  \
# 0           1997   73814.0       56708           2051.4   7024878.38
# 1           1997    6637.0        4685           2051.4    631643.29
# 2           1997     796.0          22           2051.4     75755.32
# 3           1997   19656.0   126905000           2051.4   1870661.52
# 4           1997    1739.0         794           2051.4    165500.63
# ...          ...       ...         ...              ...          ...
# 19684       1998    4000.0        2000           1498.0    395200.00
# 19685       1998    1000.0        3000           1498.0     98800.00
# 19686       1997  310883.0      440900           1356.2  29586735.11
# 19687       1997  275746.0        5488           1356.2  26242746.82
# 19688       1997  239344.0      392160           1356.2  22778368.48
#
#        Pesticide        Yield  Unnamed: 10  Unnamed: 11
# 0       22882.34     0.796087          NaN          NaN
# ...

# %%
df.groupby('Crop_Year')['Production'].mean().plot.bar()
# Out:
# <Axes: xlabel='Crop_Year'>

# %%
df.groupby('Crop_Year')['Area'].mean().plot.bar()
# Out:
# <Axes: xlabel='Crop_Year'>

# %%
df.groupby('Crop_Year')['Fertilizer'].mean().plot.bar()
# Out:
# <Axes: xlabel='Crop_Year'>

# %%
numdf.corr()
# Out:
#                  Crop_Year      Area  Production  Annual_Rainfall  Fertilizer  \
# Crop_Year         1.000000 -0.035686    0.003366        -0.011187    0.011169
# Area             -0.035686  1.000000    0.037441        -0.106054    0.973255
# Production        0.003366  0.037441    1.000000         0.029879    0.039799
# Annual_Rainfall  -0.011187 -0.106054    0.029879         1.000000   -0.109734
# Fertilizer        0.011169  0.973255    0.039799        -0.109734    1.000000
# Pesticide        -0.004657  0.973479    0.035171        -0.097657    0.954991
# Yield             0.002539  0.001858    0.570809         0.020761    0.002862
# Unnamed: 10            NaN       NaN         NaN              NaN         NaN
# Unnamed: 11            NaN       NaN         NaN              NaN         NaN
#
#                  Pesticide     Yield  Unnamed: 10  Unnamed: 11
# Crop_Year        -0.004657  0.002539          NaN          NaN
# Area              0.973479  0.001858          NaN          NaN
# ...

# %%
sn.regplot(x=df['Production'] ,y=df['Area'])
# Out:
# <Axes: xlabel='Production', ylabel='Area'>

# %%
sn.regplot(x=df['Production'] ,y=df['Fertilizer'])
# Out:
# <Axes: xlabel='Production', ylabel='Fertilizer'>

# %%
sn.regplot(x=df['Production'] ,y=df['Pesticide'])
# Out:
# <Axes: xlabel='Production', ylabel='Pesticide'>

# %%
sn.regplot(x=df['Production'] ,y=df['Annual_Rainfall'])
# Out:
# <Axes: xlabel='Production', ylabel='Annual_Rainfall'>
